# %% [markdown]
# # Polymorphism
#
# - [ ] Assignment 0
#     1. Design and implement a class representing a rectangle and operations like area, perimeter, change dimensions, report dimensions, on it. Write code to test your classes.
#     2. Design and implement classes representing a polygon shape, and derived classes like rectangle, and square with the same operations as mentioned in assignment above. Write code to test your classes.
#
# - [ ] Assignment 1
#     - Demonstration of different inheritance types with suitable examples  as discussed in lecture
#
# - [ ] Assignment 2
#     - Demonstration of polymorphism and types of polymorphisms with taking suitable example

# %%
class Employee:
    def __init__(self, name, age, id, salary):
        self.name = name
        self.age = age
        self.salary = salary
        self.id = id
    
    
        
emp1 = Employee("Avd", 18, 101, 100000)

emp2 = Employee("Avd2", 21, 102, 200000)

emp3 = Employee("Avd3", 25, 105, 300000)

# %%
#Assingment 0.1 Design and implement a class representing a rectangle and operations like area, perimeter, change dimensions, report dimensions, on it. Write code to test your classes.

class rectangle():
    def __init__(self, name, length, breadth):
        self.name = name
        self.length = length
        self.breadth = breadth
    
    def area(self):
        return self.length * self.breadth
    
    def perimeter(self):
        return 2 * (self.length + self.breadth)
    
    def report_dimensions(self):
        print("Length: ", self.length)
        print("Breadth: ", self.breadth)
    
    def change_dimensions(self, length, breadth):
        self.length = length
        self.breadth = breadth

# %%
print("Rectangle: ")
rectangle1 = rectangle("rectangle", 5, 10)
rectangle1.change_dimensions(5, 10)
rectangle1.report_dimensions()
print(rectangle1.area())
print(rectangle1.perimeter())
# Out:
# Rectangle:
# Length:  5
# Breadth:  10
# 50
# 30

# %% [markdown]
# #### Design and implement classes representing a polygon shape, and derived classes like rectangle, and square with the same operations as mentioned in assignment above. Write code to test your classes.

# %%
# Assignment 0.2 Design and implement classes representing a polygon shape, and derived classes like rectangle, and square with the same operations as mentioned in assignment above. Write code to test your classes.
class polygon:
    def __init__(self, name):
        self.name = name
    
    def area(self):
        pass
    
    def perimeter(self):
        pass

    def change_dimensions(self):
        pass
    
    def report_dimensions(self):
        pass


class rectangle(polygon):
    def __init__(self, name, length, breadth):
        super().__init__(name)
        self.length = length
        self.breadth = breadth
    
    def area(self):
        return self.length * self.breadth
    
    def perimeter(self):
        return 2 * (self.length + self.breadth)
    
    def report_dimensions(self):
        print("Length: ", self.length)
        print("Breadth: ", self.breadth)
    
    def change_dimensions(self, length, breadth):
        self.length = length
        self.breadth = breadth
    
class square(polygon):
    def __init__(self, name, side, breadth):
        super().__init__(name)
        self.length = length
    
    def area(self):
        return self.length ** 2
    
    def perimeter(self):
        return 4 * self.length
    
    def report_dimensions(self):
        print("Side Length: ", self.length)
    
    def change_dimensions(self, length, breadth):
        self.length = length

# %%
rectangle1 = rectangle("rec1", 5, 3)
rectangle1.report_dimensions()
# Out:
# Length:  5
# Breadth:  3

# %%
# Assignment 1 Demonstration of different inheritance types with suitable examples as discussed in lecture

print("1. Single Inheritance")

class A:
    def __init__(self):
        print("1")

class B(A):
    def __init__(self):
        super().__init__()
        print("2")

class C(B):
    def __init__(self):
        super().__init__()
        print("3")

c = C()

print("2. Multiple Inheritance")

class A:
    def __init__(self):
        print("1")

class B:
    def __init__(self):
        print("2")

class C(A, B):
    def __init__(self):
        super().__init__()
        print("3")

c = C()

print("3. Multilevel Inheritance")

class A:
    def __init__(self):
        print("1")

class B(A):
    def __init__(self):
        super().__init__()
        print("2")

class C(B):
    def __init__(self):
        super().__init__()
        print("3")

c = C()

print("4. Hierarchical Inheritance")

class A:
    def __init__(self):
        super().__init__()
        print("1")

class B(A):
    def __init__(self):
        super().__init__()
        print("2")

class C(A):
    def __init__(self):
        super().__init__()
        print("3")
b = B()
c = C()
# Out:
# 1. Single Inheritance
# 1
# 2
# 3
# 2. Multiple Inheritance
# 1
# 3
# 3. Multilevel Inheritance
# 1
# 2
# 3
# 4. Hierarchical Inheritance
# 1
# 2
# 1
# 3

# %%
# Assignment 2 - Demonstration of polymorphism and types of polymorphisms with taking suitable example
# operator overloading

class A:
    def __init__(self, a):
        self.a = a

    def __add__(self, o):
        return self.a + o.a

ob1 = A(1)
ob2 = A(2)

print(ob1 + ob2)


# Method overloading

class A:
    def sum(self, a=0, b=0, c=0):
        return a+b+c

ob = A()
print(ob.sum(1, 2, 3))
print(ob.sum(1, 2))
print(ob.sum(1))


# Method overriding

class A:
    def show(self):
        print("In A show")

class B(A):
    def show(self):
        print("In B show")
        
ob = B()
ob.show()
# Out:
# 3
# 6
# 3
# 1
# In B show

# %%
# Assignment 3

class BankAccount:
    def __init__(self, name, acc_no, acc_type, balance):
        self.name = name
        self.acc_no = acc_no
        self.acc_type = acc_type
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if self.balance < amount:
            print("not enough balance")
        else:
            self.balance -= amount

    def display(self):
        print("Name: ", self.name)
        print("Account number: ", self.acc_no)
        print("Account type: ", self.acc_type)
        print("Balance: ", self.balance)

# %%
# Assignment 4
name = input("Enter name: ")
acc_no = input("Enter account number: ")
acc_type = input("Enter account type: ")
balance = int(input("Enter balance: "))
b = BankAccount(name, acc_no, acc_type, balance)
while True:
    print("1. Deposit")
    print("2. Withdraw")
    print("3. Display")
    print("4. Exit")
    choice = int(input("Enter your choice: "))
    if choice == 1:
        amount = int(input("Enter amount to deposit: "))
        b.deposit(amount)
    elif choice == 2:
        amount = int(input("Enter amount to withdraw: "))
        b.withdraw(amount)
    elif choice == 3:
        b.display()
    elif choice == 4:
        break
    else:
        print("Invalid choice")
# Out:
# Enter name:  uashuag
# Enter account number:  15135
# Enter account type:  Savings
# Enter balance:  155135
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4272/2483265368.py in <module>
#       4 acc_type = input("Enter account type: ")
#       5 balance = int(input("Enter balance: "))
# ----> 6 b = BankAccount(name, acc_no, acc_type, balance)
#       7 while True:
#       8     print("1. Deposit")
#
# NameError: name 'BankAccount' is not defined

# %%
# Assignment 5
# 1. Write a program to display two labels with different colored background.

import tkinter as tk

root = tk.Tk()
root.geometry("200x100")

label1 = tk.Label(root, text="Label 1", bg="red")
label2 = tk.Label(root, text="Label 2", bg="green")

label1.pack(fill=tk.BOTH, expand=True)
label2.pack(fill=tk.BOTH, expand=True)

root.mainloop()

# %%
# Assignment 6
import tkinter as tk
from tkinter import messagebox

def display_message(message):
    messagebox.showinfo("Message", message)

def say_hello():
    display_message("Hello")

def say_something():
    display_message("Something")

root = tk.Tk()
root.geometry("200x100")

menu_bar = tk.Menu(root)

file_menu = tk.Menu(menu_bar, tearoff=0)
file_menu.add_command(label="Open")
file_menu.add_command(label="Save")
file_menu.add_separator()
file_menu.add_command(label="Exit", command=root.quit)

help_menu = tk.Menu(menu_bar, tearoff=0)
help_menu.add_command(label="About")

say_menu = tk.Menu(menu_bar, tearoff=0)
say_menu.add_command(label="Hello", command=say_hello)
say_menu.add_command(label="Something", command=say_something)

menu_bar.add_cascade(label="File", menu=file_menu)
menu_bar.add_cascade(label="Help", menu=help_menu)
menu_bar.add_cascade(label="Say", menu=say_menu)

root.config(menu=menu_bar)

root.mainloop()
